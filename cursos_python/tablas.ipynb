# %%
import pandas as pd

# %%
tabla_seq = pd.read_clipboard()

# %%
tabla_seq
# Out:
#    Sample   Raw Reads Sequencing depth (X) Reads after QC Reads after QC# %  \
# 0   IV-5^  29 191 671                84.95     22 978 888               79%
# 1   IV-2^  40 672 795               122.02     39 920 701               88%
# 2   IV-6^  43 486 476               130.46     38 353 481               88%
# 3   IV-4^  42 838 012               128.51     37 729 408               88%
# 4   IV-7^  377 188 93               113.16     33 250 705               88%
# 5    V-8^  55 720 364               222.88     51 583 390               93%
# 6    V-2^  55 054 777               160.22     37 529 435               68%
# 7    V-1^  57 215 132               166.51     34 333 842               60%
# 8   IV-6*    43486476               130,46     38 353 481               88%
# 9   IV-2*    40672795                122,2       35920701               88%
# 10  IV-4*    42838012               125,51       37729408               88%
# ...
